# %%
#upload Data set.
import pandas as pd
df2 = pd.read_excel("E:/python 776/covid.xlsx")
df2.head()
# Out:
#    id government_id       diagnosed_date  age gender  \
# 0   0      KL-TS-P1           30/01/2020   20      F
# 1   1      KL-AL-P1  2020-02-02 00:00:00  NaN    NaN
# 2   2      KL-KS-P1  2020-03-02 00:00:00  NaN    NaN
# 3   3         DL-P1  2020-02-03 00:00:00   45      M
# 4   4         TS-P1  2020-02-03 00:00:00   24      M
#
#               detected_city detected_district detected_state nationality  \
# 0                  Thrissur          Thrissur         Kerala       India
# 1                 Alappuzha         Alappuzha         Kerala       India
# 2                 Kasaragod         Kasaragod         Kerala       India
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       India
# 4                 Hyderabad         Hyderabad      Telangana       India
#
#   current_status   status_change_date                          notes
# 0      Recovered           14/02/2020           Travelled from Wuhan
# ...

# %%
df2.dtypes
# Out:
# id                     int64
# government_id         object
# diagnosed_date        object
# age                   object
# gender                object
# detected_city         object
# detected_district     object
# detected_state        object
# nationality           object
# current_status        object
# status_change_date    object
# notes                 object
# dtype: object

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = df.gender()  
y = df.gender.value_counts() 
ax.bar(x, y, inplace=True)  
ax.set_xlabel('gender')  
ax.set_ylabel('Count')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-fd21701b1346> in <module>
#       1 import matplotlib.pyplot as plt
#       2 fig, ax = plt.subplots()
# ----> 3 x = df.gender()
#       4 y = df.gender.value_counts()
#       5 ax.bar(x, y, inplace=True)
#
# TypeError: 'Series' object is not callable

# %%
df2.head()
# Out:
#    id government_id       diagnosed_date  age gender  \
# 0   0      KL-TS-P1           30/01/2020   20      F
# 1   1      KL-AL-P1  2020-02-02 00:00:00  NaN    NaN
# 2   2      KL-KS-P1  2020-03-02 00:00:00  NaN    NaN
# 3   3         DL-P1  2020-02-03 00:00:00   45      M
# 4   4         TS-P1  2020-02-03 00:00:00   24      M
#
#               detected_city detected_district detected_state nationality  \
# 0                  Thrissur          Thrissur         Kerala       India
# 1                 Alappuzha         Alappuzha         Kerala       India
# 2                 Kasaragod         Kasaragod         Kerala       India
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       India
# 4                 Hyderabad         Hyderabad      Telangana       India
#
#   current_status   status_change_date                          notes
# 0      Recovered           14/02/2020           Travelled from Wuhan
# ...

# %%
df2.head()
# Out:
#    id government_id       diagnosed_date  age gender  \
# 0   0      KL-TS-P1           30/01/2020   20      F
# 1   1      KL-AL-P1  2020-02-02 00:00:00  NaN    NaN
# 2   2      KL-KS-P1  2020-03-02 00:00:00  NaN    NaN
# 3   3         DL-P1  2020-02-03 00:00:00   45      M
# 4   4         TS-P1  2020-02-03 00:00:00   24      M
#
#               detected_city detected_district detected_state nationality  \
# 0                  Thrissur          Thrissur         Kerala       India
# 1                 Alappuzha         Alappuzha         Kerala       India
# 2                 Kasaragod         Kasaragod         Kerala       India
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       India
# 4                 Hyderabad         Hyderabad      Telangana       India
#
#   current_status   status_change_date                          notes
# 0      Recovered           14/02/2020           Travelled from Wuhan
# ...

# %%
boxplot = df2.boxplot(['nationality'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-38b8f9ee587d> in <module>
# ----> 1 boxplot = df2.boxplot(['nationality'])
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     418         layout=layout,
#     419         return_type=return_type,
# --> 420         **kwds
#     421     )
#     422
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     353         layout=layout,
#     354         return_type=return_type,
# --> 355         **kwds
#     356     )
#     357     plt.draw_if_interactive()
#
# ...

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xlrd 
  
# Give the location of the file 
  
wb = xlrd.open_workbook("E:/python 776/covid.xlsx") 
sheet = wb.sheet_by_index(0) 
sheet.cell_value(0, 0) 
  
# Extracting number of rows 
print("No. of Rows = ", sheet.nrows) 
print("No. of Cols = ", sheet.ncols)
print()
# Out:
# No. of Rows =  1305
# No. of Cols =  12

# %%
import pandas as pd
df = pd.read_excel("E:/python 776/covid.xlsx")
df.head()
# Out:
#    id government_id       diagnosed_date  age gender  \
# 0   0      KL-TS-P1           30/01/2020   20      F
# 1   1      KL-AL-P1  2020-02-02 00:00:00  NaN    NaN
# 2   2      KL-KS-P1  2020-03-02 00:00:00  NaN    NaN
# 3   3         DL-P1  2020-02-03 00:00:00   45      M
# 4   4         TS-P1  2020-02-03 00:00:00   24      M
#
#               detected_city detected_district detected_state nationality  \
# 0                  Thrissur          Thrissur         Kerala       India
# 1                 Alappuzha         Alappuzha         Kerala       India
# 2                 Kasaragod         Kasaragod         Kerala       India
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi       India
# 4                 Hyderabad         Hyderabad      Telangana       India
#
#   current_status   status_change_date                          notes
# 0      Recovered           14/02/2020           Travelled from Wuhan
# ...

# %%
df.dtypes
# Out:
# id                     int64
# government_id         object
# diagnosed_date        object
# age                   object
# gender                object
# detected_city         object
# detected_district     object
# detected_state        object
# nationality           object
# current_status        object
# status_change_date    object
# notes                 object
# dtype: object

# %%
import numpy as np
df_morph = df2[["detected_city", "detected_district", "detected_state", "gender"]].drop_duplicates()
df_morph.shape
# Out:
# (403, 4)

# %%
df_morph.head()
# Out:
#               detected_city detected_district detected_state gender
# 0                  Thrissur          Thrissur         Kerala      F
# 1                 Alappuzha         Alappuzha         Kerala    NaN
# 2                 Kasaragod         Kasaragod         Kerala    NaN
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi      M
# 4                 Hyderabad         Hyderabad      Telangana      M

# %%
df_morph.describe()
# Out:
#        detected_city detected_district detected_state gender
# count            270               372            402    279
# unique           185               150             27      2
# top        Ahmedabad         Hyderabad         Kerala      M
# freq               4                15             49    173

# %%
import pandas as pd
df = pd.read_excel("E:/python 776/covid.xlsx")
df.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                          notes
# 0         14/02/2020           Travelled from Wuhan
# ...

# %%
df.dtypes
# Out:
# id                     int64
# government_id         object
# diagnosed_date        object
# age                   object
# gender                object
# detected_city         object
# detected_district     object
# detected_state        object
# nationality           object
# current_status        object
# status_change_date    object
# notes                 object
# dtype: object

# %%
import numpy as np
df_morph = df[["detected_city", "detected_district", "detected_state", "gender"]].drop_duplicates()
df_morph.shape
# Out:
# (403, 4)

# %%
df_morph.head()
# Out:
#               detected_city detected_district detected_state gender
# 0                  Thrissur          Thrissur         Kerala      F
# 1                 Alappuzha         Alappuzha         Kerala    NaN
# 2                 Kasaragod         Kasaragod         Kerala    NaN
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi      M
# 4                 Hyderabad         Hyderabad      Telangana      M

# %%
df_morph.describe()
# Out:
#        detected_city detected_district detected_state gender
# count            270               372            402    279
# unique           185               150             27      2
# top             Pune         Hyderabad         Kerala      M
# freq               4                15             49    173

# %%
import numpy as np  
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = df.gender() 
y = df.gender.value_counts() 
ax.bar(x, y)
ax.set_xlabel('gender')  
ax.set_ylabel('Count')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-147086c80c45> in <module>
#       2 import matplotlib.pyplot as plt
#       3 fig, ax = plt.subplots()
# ----> 4 x = df.gender()
#       5 y = df.gender.value_counts()
#       6 ax.bar(x, y)
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
#sns.set_style(“ticks”)
plt.figure(figsize = (15,10))
#plt.barh(state_data['States/UT'], state_data['current_status'].map(int),align = "center", color = "lightblue", edgecolor = "blue")
plt.xlabel("No of current_status")
plt.ylabel("States/UT", fontsize = 18)
plt.gca().invert_yaxis()
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.title("Total Confirmed Cases Statewise", fontsize = 18 )
#for index, value in enumerate(state_data[“current_status”]):
    #plt.text(value, index, str(value), fontsize = 12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c5976d75cd1d> in <module>
#       2 #sns.set_style(“ticks”)
#       3 plt.figure(figsize = (15,10))
# ----> 4 plt.barh(detected_state['States/UT'], detected_state['current_status'].map(int),align = "center", color = "lightblue", edgecolor = "blue")
#       5 plt.xlabel("No of current_status")
#       6 plt.ylabel("States/UT", fontsize = 18)
#
# NameError: name 'detected_state' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_excel("E:/python 776/covid.xlsx")
df.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                          notes
# 0         14/02/2020           Travelled from Wuhan
# ...

# %%
# show the data as date wise and also show the current-status, city & gender of the patients.
df.groupby(['diagnosed_date'])['current_status', 'detected_city','gender'].max()
# Out:
#                current_status       detected_city gender
# diagnosed_date
# 02/02/2020          Recovered           Alappuzha   None
# 02/03/2020          Recovered           Hyderabad      M
# 03/02/2020          Recovered           Kasaragod   None
# 03/03/2020          Recovered              Jaipur      M
# 04/03/2020          Recovered                 NaN    NaN
# 05/03/2020          Recovered           Janakpuri      M
# 06/03/2020          Recovered         Uttam Nagar   None
# 07/03/2020          Recovered              Ladakh      M
# 08/03/2020       Hospitalized               Ranni      M
# 09/03/2020          Recovered           Tri Nagar    NaN
# 10/03/2020          Recovered               Ranni    NaN
# 11/03/2020       Hospitalized                Pune    NaN
# 12/03/2020          Recovered            Thrissur    NaN
# 13/03/2020          Recovered             Varkala    NaN
# 14/03/2020       Hospitalized            Yavatmal    NaN
# ...

# %%
import matplotlib.pyplot as plt
df.groupby(['diagnosed_date'])['current_status'].plot(kind='line'),figsize=(20,10)
# Out:
#   File "<ipython-input-45-219c5b593996>", line 2
#     df.groupby(['diagnosed_date'])['current_status'].plot(kind='line'),figsize=(20,10)
#                                                                                       ^
# SyntaxError: can't assign to function call

# %%
#give the percent wise Data in how many percent cases in that perticular areas. by using pie chart. 
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
df['detected_city'].value_counts().plot.pie(autopct="%1.1f%%")

# %%
# TO check No. of male & female. who s more.  
import matplotlib.pyplot as plt
sns.countplot(df.gender)  
plt.show()

# %%
#count the cases in detected-city.
df['detected_city'].value_counts()
# Out:
# Mumbai         67
# Bengaluru      34
# Kasaragod      26
# Pune           25
# Hyderabad      23
#                ..
# Habra           1
# Rajnandgaon     1
# Rajapalayam     1
# Imphal          1
# Kodagu          1
# Name: detected_city, Length: 185, dtype: int64

# %%
#check the nationality & counts . 
df['nationality'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
#compare male & female.
df['gender'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
#counts the currents-status of patients. how many hospitalized,Recovered, Deceased,& migrated.
df['current_status'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
# show how many states are effected.
df['detected_city'].unique()
# Out:
# array(['Thrissur', 'Alappuzha', 'Kasaragod', 'East Delhi (Mayur Vihar)',
#        'Hyderabad', 'Jaipur', 'Gurugram', 'Agra', nan, 'Janakpuri',
#        'Ghaziabad', 'Uttam Nagar', 'Ladakh', 'Kancheepuram', 'Ranni',
#        'Tri Nagar', 'Jammu', 'Bengaluru', 'Kannur', 'Pune', 'Amritsar',
#        'Kozhencherry', 'Kochi', 'Chengalam', 'Chuchot', 'Mumbai',
#        'Nellore', 'Kalaburagi', 'Nagpur', 'Thane', 'Lucknow', 'Delhi',
#        'Varkala', 'Nedumangad', 'Thiruvananthapuram', 'Ahmednagar',
#        'Yavatmal', 'Munnar', 'Aurangabad', 'Pimpri-Chinchwad', 'Dehradun',
#        'Rajouri', 'Kalanadu', 'Malappuram', 'Bhubaneswar', 'Saket',
#        'Kargil', 'Leh', 'Mahe', 'Noida', 'Kolkata', 'Bengaluru ',
#        'Gautam Buddh Nagar', 'Chennai', 'Shrungartali', 'Khanyar',
#        'Jhunjhunu', 'Dilshad Garden', 'Chandigarh', 'Kodagu', 'Ongole',
#        'Raipur', 'Lakhimpur kheri', 'Banga', 'Eriyal', 'Rajkot', 'Surat',
# ...

# %%
#count how many no. of  states are effected
len(df['detected_city'].unique())
# Out:
# 186

# %%
import pandas as pd
df = pd.read_excel("E:/python 776/covid.xlsx")
df.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                          notes
# 0         14/02/2020           Travelled from Wuhan
# ...

# %%
#check for distribution on map.paitents in percent wise in detected state.
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
df['detected_state'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
#map plot
df.plot(figsize=(20,10))

# %%
#comapre No. of cases in age wise between male & female.
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/raw_data.json" 
data = requests.get(url=URL).json()
sex=pd.DataFrame(data["raw_data"])
female=sex[sex["gender"]=="F"]
male=sex[sex["gender"]=="M"]
m_age=np.array(male['agebracket'])
a1=0
b1=0
c1=0
d1=0
e1=0
for i in m_age:
    if i>'0' and i<='20':
        a1+=1
    elif i>'20' and i<='40':
        b1+=1
    elif i>'40' and i<='60':
        c1+=1
    elif i>'60' and i<='80':
        d1+=1
    else:
        e1+=1
male_age=[a1,b1,c1,d1,e1]
f_age=np.array(female['agebracket'])
a2=0
b2=0
c2=0
d2=0
e2=0
for i in f_age:
    if i>'0' and i<='20':
        a2+=1
    elif i>'20' and i<='40':
        b2+=1
    elif i>'40' and i<='60':
        c2+=1
    elif i>'60' and i<='80':
        d2+=1
    else:
        e2+=1
female_age=[a2,b2,c2,d2,e2]
x=['0-20','21-40','41-60','61-80','81 to above']
xpos=np.arange(len(x))
plt.bar(xpos-0.2,male_age,width=0.4,label="Male")
plt.bar(xpos+0.2,female_age,width=0.4,label="Female")
plt.xticks(xpos,x)
plt.xlabel("Age")
plt.ylabel("No. of cases")
plt.legend()
plt.show()

# %%
#To check total no of cases & check  the current status how many are active. how many recovered & how many patients are deaths.
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/data.json" 
data = requests.get(url=URL).json()
covid19_df = json_normalize(data['statewise'])
stn1=input("enter the name of state :")
st1=stn1.capitalize()
c1=int(covid19_df[covid19_df.state==st1]['confirmed'])
a1=int(covid19_df[covid19_df.state==st1]['active'])
d1=int(covid19_df[covid19_df.state==st1]['deaths'])
r1=int(covid19_df[covid19_df.state==st1]['recovered'])
x1=[a1,d1,r1]
y=['active','deaths','recovered']
plt.pie(x1,labels=y,autopct='%0.2f%%',explode=[0,0.1,0])
plt.title(st1+" :Total no. of cases "+str(c1))
plt.show()
# Out:
# enter the name of state :delhi
